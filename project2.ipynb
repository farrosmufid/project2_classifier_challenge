# %% [markdown]
# ## Project 2

# %%
# import stuff
import time
import os

import numpy as np
import torch
import torch.optim as optim
from torch import nn
from torch.autograd import Variable

import torchvision
import torchvision.models as models
import torch.utils.model_zoo as model_zoo
import torchvision.transforms as transforms
from torchvision import datasets

from itertools import accumulate
from functools import reduce

# %%
import torch
import torchvision
import torchvision.transforms as transforms

data_transforms = {
    
    'train': transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]), 
    
    'val': transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]), 


}

# %% [markdown]
# ### Loading the Dataset

# %%
data_dir = 'release'
# create a dictionary that contains train and val
list_set = ['train','val']

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir,x), data_transforms[x]) for x in list_set}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size = 4, shuffle= True) for x in list_set}

trainloader, valloader = dataloaders[list_set[0]], dataloaders[list_set[1]]

dataset_sizes = {x: len(image_datasets[x]) for x in list_set}

class_names = image_datasets[list_set[0]].classes

print("Classes = {}".format(class_names))
print("Num of Classes = {}".format(len(class_names)))
print("There are {} iterations in the training set".format(len(dataloaders[list_set[0]])))
print("There are {} iterations in the valdation set".format(len(dataloaders[list_set[1]])))
print("There are {} training images".format(dataset_sizes[list_set[0]]))
print("There are {} validation images".format(dataset_sizes[list_set[1]]))
# Out:
# Classes = ['apple', 'avocado', 'banana', 'blueberry', 'cherry', 'dragonfruit', 'grape', 'kiwifruit', 'lemon', 'orange', 'papaya', 'peach', 'pear', 'pineapple', 'plum', 'pomegranate', 'rockmelon', 'strawberry']
# Num of Classes = 18
# There are 605 iterations in the training set
# There are 89 iterations in the valdation set
# There are 2417 training images
# There are 355 validation images

# %% [markdown]
# ### Loading the Resnet

# %%
net = torchvision.models.resnet152(pretrained=True) # change this to some other model
print(net)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to C:\Users\yxia2172/.torch\models\resnet152-b121ed2d.pth
# 100.0%
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# only train the last layer
# freeze all the layers
# cancels backpropagation

for param in net.parameters():
    param.requires_grad = False

# %%
num_ftrs = net.fc.in_features # get number of input features of the last fc layer

net.fc = nn.Linear(num_ftrs,18) # set the last fc to 18
print(net.fc)
# Out:
# Linear(in_features=2048, out_features=18, bias=True)

# %%
if torch.cuda.is_available():
    net = net.cuda()
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Define a Loss function and optimizer

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.fc.parameters(), lr=0.001, momentum=0.9)

print(optimizer)
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.001
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )

# %%
# lr scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# step_size = 7: change learning rate every 7 epochs.
# gamma = 0.1: learning rate * gamma when changing.
print(scheduler.base_lrs)
# Out:
# [0.001]

# %% [markdown]
# ### Visualise the Training

# %%
iteration = 0
correct = 0

for inputs, labels in dataloaders['train']:
    
    if iteration ==1:
        break
        
    inputs = Variable(inputs)
    labels = Variable(labels)
    
    if torch.cuda.is_available():
        inputs = Variable(inputs).cuda()
        labels = Variable(labels).cuda()    
        
    print("For one iteration this is what happens = ")
    print("Input Shape: ",inputs.shape)
    print("Labels Shape: ",labels.shape)
    print("Labels are: {}".format(labels))
    
    
    if torch.cuda.is_available():
        net = net.cuda()
    output = net(inputs)
    
    print("Output Tensor:",output)
    print("Output Shape: ",output.shape)
    
    _, predicted = torch.max(output,1)
    
    print("Predicted:",predicted)
    print("Predicted Shape:",predicted.shape)
    
    correct += (predicted==labels).sum()
    
    print("Correct Predictions:",correct)
    
    iteration+=1
# Out:
# For one iteration this is what happens =
# Input Shape:  torch.Size([4, 3, 224, 224])
# Labels Shape:  torch.Size([4])
# Labels are: tensor([ 4,  8, 11,  3], device='cuda:0')
# Output Tensor: tensor([[-0.0111, -0.1133,  0.0346,  0.2253,  0.6368,  0.4616,  0.8074,  0.8353,
#          -0.3990, -0.1903, -0.0093,  0.2028,  0.3743, -0.7140,  0.6758, -0.1440,
#          -0.2301, -0.0020],
#         [ 0.2480, -0.4694, -0.4127, -0.0044,  0.3652,  0.4088, -0.0519, -0.1111,
#          -0.2731, -0.3728, -0.2708, -0.3084,  0.1530,  0.0017,  0.6216,  0.1325,
#          -0.6555, -0.4703],
#         [ 0.4831, -0.4500, -0.1147,  0.4442,  0.4841,  0.2390, -0.0069,  0.0467,
#          -0.4324,  0.2923, -0.3247, -0.2483,  0.4047, -0.3839,  0.6106,  0.2156,
#          -0.1409, -0.0901],
#         [-0.0035,  0.0406, -0.5083, -0.0619,  0.5652,  0.2681,  0.1639,  0.3629,
#          -0.1505, -0.0005, -0.2689, -0.0204, -0.0253,  0.0386,  0.7711,  0.2234,
#          -0.2883,  0.0315]], device='cuda:0', grad_fn=<ThAddmmBackward>)
# Output Shape:  torch.Size([4, 18])
# Predicted: tensor([ 7, 14, 14, 14], device='cuda:0')
# Predicted Shape: torch.Size([4])
# Correct Predictions: tensor(0, device='cuda:0')

# %% [markdown]
# ### Train the Network

# %%
loss_list = []
validation_list = []
test_accuracy_list = []

for epoch in range(20):  # change this to 20
    
    correct = 0
    total = 0

    running_loss = 0.0
    validation_loss = 0.0
    
    scheduler.step()
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
        
        if torch.cuda.is_available():
            inputs = inputs.cuda()
            labels = labels.cuda()
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        
        if i % 50 == 49:    
            
            loss_list.append(running_loss/50)
            
            print('[%d, %5d] running loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 50))
            running_loss = 0.0
        
    for i, data in enumerate(valloader, 0):
        
        inputs, labels = data
        
        if torch.cuda.is_available():
            inputs = inputs.cuda()
            labels = labels.cuda()

        outputs = net(inputs)
        val_loss = criterion(outputs, labels)
        validation_loss += val_loss.item()
        
        if i % 10 == 9:    
            
            validation_list.append(validation_loss/10)
            
            print('[%d, %5d] validation loss: %.3f' %
                  (epoch + 1, i + 1, validation_loss/10))
            
            validation_loss = 0.0
            
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()    
    
    print("Test Accuracy: {:.3f}%".format(100*correct/total))
    
    test_accuracy = 100*correct/total
    
    test_accuracy_list.append(test_accuracy)
        
print('Finished Training')
# Out:
# [1,    50] running loss: 2.971
# [1,   100] running loss: 2.691
# [1,   150] running loss: 2.187
# [1,   200] running loss: 2.041
# [1,   250] running loss: 1.965
# [1,   300] running loss: 1.810
# [1,   350] running loss: 1.571
# [1,   400] running loss: 1.514
# [1,   450] running loss: 1.544
# [1,   500] running loss: 1.331
# [1,   550] running loss: 1.407
# [1,   600] running loss: 1.296
# [1,    10] validation loss: 1.084
# [1,    20] validation loss: 0.937
# [1,    30] validation loss: 1.106
# [1,    40] validation loss: 1.173
# [1,    50] validation loss: 1.136
# [1,    60] validation loss: 1.500
# [1,    70] validation loss: 1.205
# [1,    80] validation loss: 1.389
# Test Accuracy: 67.042%
# [2,    50] running loss: 1.165
# [2,   100] running loss: 1.063
# [2,   150] running loss: 1.166
# [2,   200] running loss: 1.318
# [2,   250] running loss: 1.030
# [2,   300] running loss: 1.003
# [2,   350] running loss: 0.981
# [2,   400] running loss: 1.009
# [2,   450] running loss: 1.074
# [2,   500] running loss: 0.989
# [2,   550] running loss: 1.170
# [2,   600] running loss: 0.954
# [2,    10] validation loss: 1.046
# [2,    20] validation loss: 1.148
# [2,    30] validation loss: 1.025
# [2,    40] validation loss: 0.722
# [2,    50] validation loss: 0.928
# [2,    60] validation loss: 0.779
# [2,    70] validation loss: 0.920
# [2,    80] validation loss: 1.059
# Test Accuracy: 73.239%
# [3,    50] running loss: 1.121
# [3,   100] running loss: 0.837
# [3,   150] running loss: 0.976
# [3,   200] running loss: 1.024
# [3,   250] running loss: 0.898
# [3,   300] running loss: 0.864
# [3,   350] running loss: 0.901
# [3,   400] running loss: 0.882
# [3,   450] running loss: 0.931
# [3,   500] running loss: 0.865
# [3,   550] running loss: 0.779
# [3,   600] running loss: 0.960
# [3,    10] validation loss: 0.941
# [3,    20] validation loss: 1.169
# [3,    30] validation loss: 1.074
# [3,    40] validation loss: 1.287
# [3,    50] validation loss: 0.833
# [3,    60] validation loss: 0.713
# [3,    70] validation loss: 0.855
# [3,    80] validation loss: 0.924
# Test Accuracy: 70.423%
# [4,    50] running loss: 0.863
# [4,   100] running loss: 0.703
# [4,   150] running loss: 0.726
# [4,   200] running loss: 0.817
# [4,   250] running loss: 0.868
# [4,   300] running loss: 0.734
# [4,   350] running loss: 0.862
# [4,   400] running loss: 0.781
# [4,   450] running loss: 0.911
# [4,   500] running loss: 0.826
# [4,   550] running loss: 0.803
# [4,   600] running loss: 0.833
# [4,    10] validation loss: 0.713
# [4,    20] validation loss: 0.658
# [4,    30] validation loss: 1.280
# [4,    40] validation loss: 0.855
# [4,    50] validation loss: 0.904
# [4,    60] validation loss: 0.808
# [4,    70] validation loss: 0.719
# [4,    80] validation loss: 0.684
# Test Accuracy: 77.746%
# [5,    50] running loss: 0.757
# [5,   100] running loss: 0.791
# [5,   150] running loss: 0.731
# [5,   200] running loss: 0.684
# [5,   250] running loss: 0.856
# [5,   300] running loss: 0.696
# [5,   350] running loss: 0.841
# [5,   400] running loss: 0.701
# [5,   450] running loss: 0.772
# [5,   500] running loss: 0.676
# [5,   550] running loss: 0.847
# [5,   600] running loss: 0.790
# [5,    10] validation loss: 0.994
# [5,    20] validation loss: 0.658
# [5,    30] validation loss: 0.821
# [5,    40] validation loss: 0.708
# [5,    50] validation loss: 0.489
# [5,    60] validation loss: 0.653
# [5,    70] validation loss: 0.606
# [5,    80] validation loss: 0.857
# Test Accuracy: 78.310%
# [6,    50] running loss: 0.739
# [6,   100] running loss: 0.523
# [6,   150] running loss: 0.818
# [6,   200] running loss: 0.739
# [6,   250] running loss: 0.764
# [6,   300] running loss: 0.775
# [6,   350] running loss: 0.765
# [6,   400] running loss: 0.717
# [6,   450] running loss: 0.639
# [6,   500] running loss: 0.785
# [6,   550] running loss: 0.758
# [6,   600] running loss: 0.668
# [6,    10] validation loss: 1.039
# [6,    20] validation loss: 0.908
# [6,    30] validation loss: 0.883
# [6,    40] validation loss: 0.863
# [6,    50] validation loss: 0.560
# [6,    60] validation loss: 0.770
# [6,    70] validation loss: 0.712
# [6,    80] validation loss: 1.079
# Test Accuracy: 72.394%
# [7,    50] running loss: 0.655
# [7,   100] running loss: 0.750
# [7,   150] running loss: 0.762
# [7,   200] running loss: 0.578
# [7,   250] running loss: 0.659
# [7,   300] running loss: 0.597
# [7,   350] running loss: 0.638
# [7,   400] running loss: 0.708
# [7,   450] running loss: 0.776
# [7,   500] running loss: 0.706
# [7,   550] running loss: 0.805
# [7,   600] running loss: 0.624
# [7,    10] validation loss: 0.755
# [7,    20] validation loss: 0.483
# [7,    30] validation loss: 0.610
# [7,    40] validation loss: 0.463
# [7,    50] validation loss: 0.849
# [7,    60] validation loss: 0.723
# [7,    70] validation loss: 0.639
# [7,    80] validation loss: 1.284
# Test Accuracy: 81.127%
# [8,    50] running loss: 0.561
# [8,   100] running loss: 0.548
# [8,   150] running loss: 0.660
# [8,   200] running loss: 0.596
# [8,   250] running loss: 0.545
# [8,   300] running loss: 0.614
# [8,   350] running loss: 0.480
# [8,   400] running loss: 0.642
# [8,   450] running loss: 0.581
# [8,   500] running loss: 0.598
# [8,   550] running loss: 0.526
# [8,   600] running loss: 0.633
# [8,    10] validation loss: 0.579
# [8,    20] validation loss: 0.782
# [8,    30] validation loss: 0.442
# [8,    40] validation loss: 0.660
# [8,    50] validation loss: 0.724
# [8,    60] validation loss: 0.771
# [8,    70] validation loss: 0.658
# [8,    80] validation loss: 0.453
# Test Accuracy: 81.127%
# [9,    50] running loss: 0.502
# [9,   100] running loss: 0.464
# [9,   150] running loss: 0.547
# [9,   200] running loss: 0.492
# [9,   250] running loss: 0.589
# [9,   300] running loss: 0.683
# [9,   350] running loss: 0.545
# [9,   400] running loss: 0.505
# [9,   450] running loss: 0.544
# [9,   500] running loss: 0.507
# [9,   550] running loss: 0.583
# [9,   600] running loss: 0.632
# [9,    10] validation loss: 0.401
# [9,    20] validation loss: 0.498
# [9,    30] validation loss: 0.776
# [9,    40] validation loss: 0.990
# [9,    50] validation loss: 0.543
# [9,    60] validation loss: 0.791
# [9,    70] validation loss: 0.811
# [9,    80] validation loss: 0.526
# Test Accuracy: 80.282%
# [10,    50] running loss: 0.527
# [10,   100] running loss: 0.588
# [10,   150] running loss: 0.641
# [10,   200] running loss: 0.480
# [10,   250] running loss: 0.520
# [10,   300] running loss: 0.610
# [10,   350] running loss: 0.651
# [10,   400] running loss: 0.494
# [10,   450] running loss: 0.491
# [10,   500] running loss: 0.537
# [10,   550] running loss: 0.577
# [10,   600] running loss: 0.473
# [10,    10] validation loss: 0.636
# [10,    20] validation loss: 0.856
# [10,    30] validation loss: 0.851
# [10,    40] validation loss: 0.686
# [10,    50] validation loss: 0.942
# [10,    60] validation loss: 0.446
# [10,    70] validation loss: 0.792
# [10,    80] validation loss: 0.483
# Test Accuracy: 79.437%
# [11,    50] running loss: 0.581
# [11,   100] running loss: 0.538
# [11,   150] running loss: 0.481
# [11,   200] running loss: 0.532
# [11,   250] running loss: 0.465
# [11,   300] running loss: 0.481
# [11,   350] running loss: 0.591
# [11,   400] running loss: 0.536
# [11,   450] running loss: 0.526
# [11,   500] running loss: 0.688
# [11,   550] running loss: 0.475
# [11,   600] running loss: 0.629
# [11,    10] validation loss: 0.963
# [11,    20] validation loss: 0.604
# [11,    30] validation loss: 0.581
# [11,    40] validation loss: 0.610
# [11,    50] validation loss: 0.492
# [11,    60] validation loss: 0.538
# [11,    70] validation loss: 0.444
# [11,    80] validation loss: 0.593
# Test Accuracy: 82.254%
# [12,    50] running loss: 0.515
# [12,   100] running loss: 0.691
# [12,   150] running loss: 0.621
# [12,   200] running loss: 0.515
# [12,   250] running loss: 0.527
# [12,   300] running loss: 0.559
# [12,   350] running loss: 0.468
# [12,   400] running loss: 0.495
# [12,   450] running loss: 0.524
# [12,   500] running loss: 0.532
# [12,   550] running loss: 0.513
# [12,   600] running loss: 0.464
# [12,    10] validation loss: 0.448
# [12,    20] validation loss: 0.515
# [12,    30] validation loss: 0.273
# [12,    40] validation loss: 0.692
# [12,    50] validation loss: 0.649
# [12,    60] validation loss: 0.681
# [12,    70] validation loss: 1.088
# [12,    80] validation loss: 0.947
# Test Accuracy: 80.282%
# [13,    50] running loss: 0.472
# [13,   100] running loss: 0.568
# [13,   150] running loss: 0.451
# [13,   200] running loss: 0.444
# [13,   250] running loss: 0.522
# [13,   300] running loss: 0.589
# [13,   350] running loss: 0.599
# [13,   400] running loss: 0.532
# [13,   450] running loss: 0.621
# [13,   500] running loss: 0.479
# [13,   550] running loss: 0.404
# [13,   600] running loss: 0.648
# [13,    10] validation loss: 0.700
# [13,    20] validation loss: 0.293
# [13,    30] validation loss: 0.480
# [13,    40] validation loss: 0.352
# [13,    50] validation loss: 0.705
# [13,    60] validation loss: 0.509
# [13,    70] validation loss: 0.598
# [13,    80] validation loss: 0.831
# Test Accuracy: 85.634%
# [14,    50] running loss: 0.490
# [14,   100] running loss: 0.600
# [14,   150] running loss: 0.487
# [14,   200] running loss: 0.507
# [14,   250] running loss: 0.543
# [14,   300] running loss: 0.410
# [14,   350] running loss: 0.468
# [14,   400] running loss: 0.441
# [14,   450] running loss: 0.487
# [14,   500] running loss: 0.527
# [14,   550] running loss: 0.572
# [14,   600] running loss: 0.635
# [14,    10] validation loss: 0.253
# [14,    20] validation loss: 0.527
# [14,    30] validation loss: 0.452
# [14,    40] validation loss: 0.705
# [14,    50] validation loss: 0.724
# [14,    60] validation loss: 0.578
# [14,    70] validation loss: 0.536
# [14,    80] validation loss: 0.801
# Test Accuracy: 81.972%
# [15,    50] running loss: 0.575
# [15,   100] running loss: 0.427
# [15,   150] running loss: 0.443
# [15,   200] running loss: 0.568
# [15,   250] running loss: 0.418
# [15,   300] running loss: 0.522
# [15,   350] running loss: 0.615
# [15,   400] running loss: 0.472
# [15,   450] running loss: 0.656
# [15,   500] running loss: 0.592
# [15,   550] running loss: 0.495
# [15,   600] running loss: 0.435
# [15,    10] validation loss: 0.409
# [15,    20] validation loss: 0.299
# [15,    30] validation loss: 0.587
# [15,    40] validation loss: 0.354
# [15,    50] validation loss: 0.574
# [15,    60] validation loss: 0.640
# [15,    70] validation loss: 0.769
# [15,    80] validation loss: 0.730
# Test Accuracy: 81.690%
# [16,    50] running loss: 0.540
# [16,   100] running loss: 0.537
# [16,   150] running loss: 0.582
# [16,   200] running loss: 0.563
# [16,   250] running loss: 0.591
# [16,   300] running loss: 0.634
# [16,   350] running loss: 0.540
# [16,   400] running loss: 0.508
# [16,   450] running loss: 0.428
# [16,   500] running loss: 0.485
# [16,   550] running loss: 0.504
# [16,   600] running loss: 0.527
# [16,    10] validation loss: 0.686
# [16,    20] validation loss: 0.604
# [16,    30] validation loss: 0.698
# [16,    40] validation loss: 0.606
# [16,    50] validation loss: 0.482
# [16,    60] validation loss: 0.787
# [16,    70] validation loss: 0.377
# [16,    80] validation loss: 0.891
# Test Accuracy: 80.000%
# [17,    50] running loss: 0.540
# [17,   100] running loss: 0.560
# [17,   150] running loss: 0.470
# [17,   200] running loss: 0.486
# [17,   250] running loss: 0.480
# [17,   300] running loss: 0.475
# [17,   350] running loss: 0.520
# [17,   400] running loss: 0.465
# [17,   450] running loss: 0.459
# [17,   500] running loss: 0.515
# [17,   550] running loss: 0.571
# [17,   600] running loss: 0.462
# [17,    10] validation loss: 0.789
# [17,    20] validation loss: 0.680
# [17,    30] validation loss: 0.746
# [17,    40] validation loss: 0.507
# [17,    50] validation loss: 0.580
# [17,    60] validation loss: 0.468
# [17,    70] validation loss: 0.590
# [17,    80] validation loss: 1.017
# Test Accuracy: 80.845%
# [18,    50] running loss: 0.593
# [18,   100] running loss: 0.539
# [18,   150] running loss: 0.495
# [18,   200] running loss: 0.467
# [18,   250] running loss: 0.485
# [18,   300] running loss: 0.488
# [18,   350] running loss: 0.575
# [18,   400] running loss: 0.584
# [18,   450] running loss: 0.635
# [18,   500] running loss: 0.467
# [18,   550] running loss: 0.592
# [18,   600] running loss: 0.581
# [18,    10] validation loss: 0.548
# [18,    20] validation loss: 0.504
# [18,    30] validation loss: 0.421
# [18,    40] validation loss: 0.569
# [18,    50] validation loss: 0.680
# [18,    60] validation loss: 0.655
# [18,    70] validation loss: 0.590
# [18,    80] validation loss: 0.382
# Test Accuracy: 83.662%
# [19,    50] running loss: 0.542
# [19,   100] running loss: 0.655
# [19,   150] running loss: 0.524
# [19,   200] running loss: 0.483
# [19,   250] running loss: 0.589
# [19,   300] running loss: 0.703
# [19,   350] running loss: 0.487
# [19,   400] running loss: 0.464
# [19,   450] running loss: 0.430
# [19,   500] running loss: 0.500
# [19,   550] running loss: 0.469
# [19,   600] running loss: 0.643
# [19,    10] validation loss: 0.373
# [19,    20] validation loss: 0.449
# [19,    30] validation loss: 0.642
# [19,    40] validation loss: 0.484
# [19,    50] validation loss: 0.654
# [19,    60] validation loss: 0.809
# [19,    70] validation loss: 0.634
# [19,    80] validation loss: 0.453
# Test Accuracy: 85.070%
# [20,    50] running loss: 0.397
# [20,   100] running loss: 0.508
# [20,   150] running loss: 0.489
# [20,   200] running loss: 0.539
# [20,   250] running loss: 0.510
# [20,   300] running loss: 0.545
# [20,   350] running loss: 0.710
# [20,   400] running loss: 0.513
# [20,   450] running loss: 0.446
# [20,   500] running loss: 0.580
# [20,   550] running loss: 0.469
# [20,   600] running loss: 0.541
# [20,    10] validation loss: 0.478
# [20,    20] validation loss: 0.747
# [20,    30] validation loss: 0.435
# [20,    40] validation loss: 0.612
# [20,    50] validation loss: 0.636
# [20,    60] validation loss: 0.903
# [20,    70] validation loss: 0.962
# [20,    80] validation loss: 0.523
# Test Accuracy: 79.437%
# Finished Training

# %% [markdown]
# ##### Visualise the loss and accuracy
# Using the loss of both training data and validation data to evaluate the model.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

running_loss_list_per_epoch = loss_list[11::12]

print('running_lost_list_per_epoch=',running_loss_list_per_epoch)

validation_loss_list_per_epoch = validation_list[7::8]

print('running_lost_list_per_epoch=',validation_loss_list_per_epoch)

plt.plot(range(len(running_loss_list_per_epoch)),running_loss_list_per_epoch)

plt.plot(range(len(validation_loss_list_per_epoch)),validation_loss_list_per_epoch) 

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss','Validation Loss'])

plt.figure()

plt.plot(range(len(test_accuracy_list)), test_accuracy_list)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.figure()
# Out:
# running_lost_list_per_epoch= [1.2959958076477052, 0.9535648155212403, 0.9596365809440612, 0.8332615709304809, 0.7903946161270141, 0.6679976105690002, 0.6237064349651337, 0.6332685470581054, 0.6323117649555207, 0.4730096960067749, 0.6285996520519257, 0.4640813076496124, 0.6476143729686737, 0.6347511589527131, 0.4349944341182709, 0.5271975469589233, 0.46227937936782837, 0.5807546257972718, 0.6431719970703125, 0.541146297454834]
# running_lost_list_per_epoch= [1.3890887022018432, 1.058544921875, 0.9237700581550599, 0.6840840101242065, 0.857282030582428, 1.0790245175361632, 1.28360658288002, 0.45297223925590513, 0.5262704074382782, 0.4825898051261902, 0.592872828245163, 0.9474837779998779, 0.831027752161026, 0.8011937022209168, 0.7300401270389557, 0.8911127746105194, 1.0170393109321594, 0.38165735006332396, 0.45306716561317445, 0.523320871591568]

# %% [markdown]
# ### Eval the trained network

# %%
# net.eval()
def eval_net(net, valloader):
    correct = 0
    total = 0
    
    with torch.no_grad():
        
        for data in valloader:
            
            images, labels = data
            
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()
            
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Test Accuracy: {:.3f} %'.format(100*correct/total))

eval_net(net, valloader)
# Out:
# Test Accuracy: 83.944 %

# %% [markdown]
# ### Visualise Our Predictions

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
shown_batch = 0
index = 0

with torch.no_grad():
    for(images, labels) in dataloaders['val']:
        if shown_batch ==1:
            break
        shown_batch += 1
        images = Variable(images)
        labels = Variable(labels)
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
            
        outputs = net(images) # the output has shape (4,18)
        _,preds = torch.max(outputs,1) # the pred has shape [0-17,0-17,0-17,0-17]
        
        for i in range(4):
            index += 1
            ax = plt.subplot(2,2,index)
            ax.axis('off')
            ax.set_title('Predicted Label: {}'.format(class_names[preds[i]]))
            input_img = images.cpu().data[i] # get the tensor of the image and put it to cpu
            inp = input_img.numpy().transpose((1,2,0)) # if we have (1,2,3) -> (2,3,1)
            mean = np.array([0.485, 0.456, 0.406])
            std = np.array([0.229, 0.224, 0.225])
            inp = (std*inp) + mean
            inp = np.clip(inp,0,1)
            plt.imshow(inp)

# %% [markdown]
# ### References
# - https://www.w3schools.com/python/python_dictionaries.asp
# - https://www.programcreek.com/python/example/105102/torchvision.datasets.ImageFolder
# - https://stackoverflow.com/questions/14826888/python-os-path-join-on-a-list
# - https://github.com/pytorch/vision/tree/master/torchvision/models

# %%
# save the model
torch.save(net.state_dict(),'resnet152.pth')
# torch.save(net.state_dict(),'project2.pth')

# %%
# load the model
net = Network(pretrained = True)
net.load_state_dict(torch.load('resnet18.pth'))
net.eval()
